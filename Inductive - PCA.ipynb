# %%
#carga de datasets
from utils.DatasetStorage import Dataset
from utils.paths import *

#clasificadores
from utils.clasificacion import *

#adaptacion
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

#otros
import os
import numpy as np
import pandas as pd
from sklearn.externals import joblib
import itertools

#variables para guardar los resultados
tipo = pruebas[3]

# %% [markdown]
# # Pruebas con el dataset Amazon (3000 Dimensiones)

# %%
dims = 3000
dataset_name = datasets[0]

# %%
print tipo
print dataset_name
print dims
print data_path
# Out:
# pca
# amazon
# 3000
# data

# %%
# cargando dataset
dataset_path = os.path.join(data_path, dataset_name+'.pkl')
dataset_object = Dataset().load(dataset_path)

dataset_object.split_dataset(test_size=0.2)

labeled = dataset_object.labeled
domains = dataset_object.domains
# Out:
# Dataset already splitted

# %%
parametros = {
    'n_components': [int(dims/2), int(dims/3), int(dims/4)],
}

# %%
porcentajes = [25, 50, 100]
modelos = {}

pairs = list(itertools.permutations(domains, 2))

for src, tgt in pairs:
    modelos[(src, tgt)] = {}
    for ptje in porcentajes:
        modelos[(src, tgt)][ptje] = [100, None]

# %%
df = pd.DataFrame(columns=dataframe_columns+['Porcentaje'])

i=0
j=0
tareas = len(domains)*(len(domains)-1)
pairs = list(itertools.permutations(domains, 2))

porcentajes = [25, 50, 100]


for src, tgt in pairs:
    print "Tarea %d de %d" % (i+1, tareas)
    tarea = src[0]+'->'+tgt[0]
    
    #datos de entrenamiento
    X_src = labeled[src]['X_tr'][:, :dims].todense()
    y_src = np.asarray(labeled[src]['y_tr'].todense()).argmax(axis=1)
    
    X_tgt = labeled[tgt]['X_tr'][:, :dims].todense()
    y_tgt = np.asarray(labeled[tgt]['y_tr'].todense()).argmax(axis=1)
    
    X_train = np.concatenate((X_src, X_tgt))
    
    #datos de prueba
    X_tgt_ts = labeled[tgt]['X_ts'][:, :dims].todense()
    y_tgt_ts = np.asarray(labeled[tgt]['y_ts'].todense()).argmax(axis=1)
    
    
    #baseline in-domain error
    model_name = "%d_%s.pkl" % (dims, tgt)
    model_path = os.path.join(models_path, dataset_name, "indomain", model_name)
    
    #Se realiza una clasificacion, estimando los parametros mediante cv
    svc = load_best_score(model_path, X_tgt, y_tgt)
    b_error = 1-svc.score(X_tgt_ts, y_tgt_ts)

    k = 0    
    for n_components in parametros['n_components']:
        print "\tEntrenando modelo de adaptacion %d" % k
        # entrenar un modelo de adaptacion
        modelo_temp = PCA(n_components=n_components)
        t_adaptar = modelo_temp.fit(X_train)

        # entrenar un clasificador con los datos adaptados
        X_src_a = modelo_temp.transform(X_src)
        clf = get_best_score(X_src_a, y_src, classifier='SVC', n_jobs=4)

        # se prueba con distintos porcentajes
        j = i*3
        for porcentaje in porcentajes:
            if porcentaje == 100:
                X_test_pc, y_test_pc = X_tgt_ts, y_tgt_ts
            else:
                X_test_pc, _, y_test_pc, _ = train_test_split(X_tgt_ts, y_tgt_ts, train_size=porcentaje/float(100))
            
            X_test_pc_a = modelo_temp.transform(X_test_pc)
            t_error = 1-clf.score(X_test_pc_a, y_test_pc)
            
            if t_error <= modelos[(src, tgt)][porcentaje][0]:
                modelos[(src, tgt)][porcentaje] = [t_error, modelo_temp]
                t_loss = t_error - b_error
                df.loc[j] = ['PCA', tarea, src, tgt, b_error*100, t_error*100, t_loss*100, porcentaje]
    
            j += 1
        k += 1
    i+=1
# Out:
# Tarea 1 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 2 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 3 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 4 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 5 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 6 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 7 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 8 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 9 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 10 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 11 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 12 de 12
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2

# %%
df
# Out:
#    Adaptacion Tarea       Fuente     Objetivo  Baseline error  Transfer error  \
# 0        mSDA  e->d  electronics          dvd       15.762894       25.320513
# 1        mSDA  e->d  electronics          dvd       15.762894       24.320802
# 2        mSDA  e->d  electronics          dvd       15.762894       26.553164
# 3        mSDA  e->k  electronics      kitchen        8.587715        8.480000
# 4        mSDA  e->k  electronics      kitchen        8.587715        7.628824
# 5        mSDA  e->k  electronics      kitchen        8.587715       10.105253
# 6        mSDA  e->b  electronics        books       15.157879       22.560000
# 7        mSDA  e->b  electronics        books       15.157879       26.842949
# 8        mSDA  e->b  electronics        books       15.157879       26.368159
# 9        mSDA  d->e          dvd  electronics       11.127778       19.871538
# 10       mSDA  d->e          dvd  electronics       11.127778       23.801421
# 11       mSDA  d->e          dvd  electronics       11.127778       24.983125
# 12       mSDA  d->k          dvd      kitchen        8.587715       19.607843
# 13       mSDA  d->k          dvd      kitchen        8.587715       19.208020
# 14       mSDA  d->k          dvd      kitchen        8.587715       18.907973
# 15       mSDA  d->b          dvd        books       15.157879       15.097403
# 16       mSDA  d->b          dvd        books       15.157879       23.422342
# 17       mSDA  d->b          dvd        books       15.157879       24.878122
# 18       mSDA  k->e      kitchen  electronics       11.127778        4.656764
# 19       mSDA  k->e      kitchen  electronics       11.127778        9.540954
# 20       mSDA  k->e      kitchen  electronics       11.127778       12.490312
# 21       mSDA  k->d      kitchen          dvd       15.762894       29.791667
# 22       mSDA  k->d      kitchen          dvd       15.762894       26.422276
# 23       mSDA  k->d      kitchen          dvd       15.762894       27.645691
# 24       mSDA  k->b      kitchen        books       15.157879       26.254516
# 25       mSDA  k->b      kitchen        books       15.157879       29.654135
# 26       mSDA  k->b      kitchen        books       15.157879       30.330758
# 27       mSDA  b->e        books  electronics       11.127778       21.898990
# 28       mSDA  b->e        books  electronics       11.127778       19.100561
# 29       mSDA  b->e        books  electronics       11.127778       20.748019
# 30       mSDA  b->d        books          dvd       15.762894       14.685874
# 31       mSDA  b->d        books          dvd       15.762894       18.200000
# 32       mSDA  b->d        books          dvd       15.762894       18.250456
# 33       mSDA  b->k        books      kitchen        8.587715       16.900843
# 34       mSDA  b->k        books      kitchen        8.587715       18.617447
# 35       mSDA  b->k        books      kitchen        8.587715       17.875447
#
#     Transfer loss Porcentaje
# 0        9.557619         25
# 1        8.557908         50
# 2       10.790270        100
# 3       -0.107715         25
# 4       -0.958890         50
# 5        1.517538        100
# 6        7.402121         25
# 7       11.685070         50
# 8       11.210280        100
# 9        8.743759         25
# 10      12.673643         50
# 11      13.855346        100
# 12      11.020128         25
# 13      10.620305         50
# 14      10.320258        100
# 15      -0.060476         25
# 16       8.264463         50
# 17       9.720243        100
# 18      -6.471014         25
# 19      -1.586824         50
# 20       1.362534        100
# 21      14.028773         25
# 22      10.659382         50
# 23      11.882797        100
# 24      11.096637         25
# 25      14.496256         50
# 26      15.172879        100
# 27      10.771212         25
# 28       7.972783         50
# 29       9.620241        100
# 30      -1.077020         25
# 31       2.437106         50
# 32       2.487562        100
# 33       8.313128         25
# 34      10.029732         50
# 35       9.287732        100

# %%
new_scores_path = os.path.join(scores_path,dataset_name, tipo, "inductive_%d.csv" % (dims))

print "Guardando en %s" % new_scores_path
df.to_csv(new_scores_path, columns=df.columns)
print "Resultados guardados."
# Out:
# Guardando en scores/amazon/pca/inductive_3000.csv
# Resultados guardados.

# %% [markdown]
# # Pruebas con el dataset Twitter (2000 Dimensiones)

# %%
dims = 2000
dataset_name = datasets[1]

# %%
print tipo
print dataset_name
print dims
print data_path
# Out:
# pca
# twitter
# 2000
# data

# %%
# cargando dataset
dataset_path = os.path.join(data_path, dataset_name+'.pkl')
dataset_object = Dataset().load(dataset_path)

dataset_object.split_dataset(test_size=0.2)

labeled = dataset_object.labeled
domains = dataset_object.domains
# Out:
# Dataset already splitted

# %%
parametros = {
    'n_components': [int(dims/2), int(dims/3), int(dims/4)],
}

# %%
porcentajes = [25, 50, 100]
modelos = {}

pairs = list(itertools.permutations(domains, 2))

for src, tgt in pairs:
    modelos[(src, tgt)] = {}
    for ptje in porcentajes:
        modelos[(src, tgt)][ptje] = [100, None]

# %%
df = pd.DataFrame(columns=dataframe_columns+['Porcentaje'])

i=0
j=0
tareas = len(domains)*(len(domains)-1)
pairs = list(itertools.permutations(domains, 2))

porcentajes = [25, 50, 100]

for src, tgt in pairs:
    print "Tarea %d de %d" % (i+1, tareas)
    tarea = src[0]+'->'+tgt[0]
    
    #datos de entrenamiento
    X_src = labeled[src]['X_tr'][:, :dims].todense()
    y_src = np.asarray(labeled[src]['y_tr'].todense()).argmax(axis=1)
    
    X_tgt = labeled[tgt]['X_tr'][:, :dims].todense()
    y_tgt = np.asarray(labeled[tgt]['y_tr'].todense()).argmax(axis=1)
    
    X_train = np.concatenate((X_src, X_tgt))
    
    #datos de prueba
    X_tgt_ts = labeled[tgt]['X_ts'][:, :dims].todense()
    y_tgt_ts = np.asarray(labeled[tgt]['y_ts'].todense()).argmax(axis=1)
    
    
    #baseline in-domain error
    model_name = "%d_%s.pkl" % (dims, tgt)
    model_path = os.path.join(models_path, dataset_name, "indomain", model_name)
    
    #Se realiza una clasificacion, estimando los parametros mediante cv
    svc = load_best_score(model_path, X_tgt, y_tgt)
    b_error = 1-svc.score(X_tgt_ts, y_tgt_ts)

    k = 0    
    for n_components in parametros['n_components']:
        print "\tEntrenando modelo de adaptacion %d" % k
        # entrenar un modelo de adaptacion
        modelo_temp = PCA(n_components=n_components)
        t_adaptar = modelo_temp.fit(X_train)

        # entrenar un clasificador con los datos adaptados
        X_src_a = modelo_temp.transform(X_src)
        clf = get_best_score(X_src_a, y_src, classifier='SVC', n_jobs=4)

        # se prueba con distintos porcentajes
        j = i*3
        for porcentaje in porcentajes:
            if porcentaje == 100:
                X_test_pc, y_test_pc = X_tgt_ts, y_tgt_ts
            else:
                X_test_pc, _, y_test_pc, _ = train_test_split(X_tgt_ts, y_tgt_ts, train_size=porcentaje/float(100))
            
            X_test_pc_a = modelo_temp.transform(X_test_pc)
            t_error = 1-clf.score(X_test_pc_a, y_test_pc)
            
            if t_error <= modelos[(src, tgt)][porcentaje][0]:
                modelos[(src, tgt)][porcentaje] = [t_error, modelo_temp]
                t_loss = t_error - b_error
                df.loc[j] = ['PCA', tarea, src, tgt, b_error*100, t_error*100, t_loss*100, porcentaje]
    
            j += 1
        k += 1
    i+=1
# Out:
# Tarea 1 de 6
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 2 de 6
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 3 de 6
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 4 de 6
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# tEntrenando modelo de adaptacion 1
# tEntrenando modelo de adaptacion 2
# Tarea 5 de 6
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# tEntrenando modelo de adaptacion 1
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# tEntrenando modelo de adaptacion 2
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Tarea 6 de 6
# Cargando modelo existente.
# tEntrenando modelo de adaptacion 0
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# tEntrenando modelo de adaptacion 1
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# tEntrenando modelo de adaptacion 2
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /home/ubuntu/anaconda2/envs/env_memoria/lib/python2.7/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %%
df
# Out:
#    Adaptacion Tarea    Fuente  Objetivo  Baseline error  Transfer error  \
# 0        mSDA  r->t   rio2016  thevoice        7.362689       13.765182
# 1        mSDA  r->t   rio2016  thevoice        7.362689       12.355212
# 2        mSDA  r->t   rio2016  thevoice        7.362689       20.383523
# 3        mSDA  r->g   rio2016   general       26.998127       43.194951
# 4        mSDA  r->g   rio2016   general       26.998127       39.232334
# 5        mSDA  r->g   rio2016   general       26.998127       42.895012
# 6        mSDA  t->r  thevoice   rio2016       10.208711        0.699301
# 7        mSDA  t->r  thevoice   rio2016       10.208711        5.643739
# 8        mSDA  t->r  thevoice   rio2016       10.208711       13.747731
# 9        mSDA  t->g  thevoice   general       26.998127       39.184556
# 10       mSDA  t->g  thevoice   general       26.998127       38.927469
# 11       mSDA  t->g  thevoice   general       26.998127       40.027036
# 12       mSDA  g->r   general   rio2016       10.208711        5.185185
# 13       mSDA  g->r   general   rio2016       10.208711       21.296296
# 14       mSDA  g->r   general   rio2016       10.208711       18.647913
# 15       mSDA  g->t   general  thevoice        7.362689       18.039216
# 16       mSDA  g->t   general  thevoice        7.362689       15.428571
# 17       mSDA  g->t   general  thevoice        7.362689       18.110795
#
#     Transfer loss Porcentaje
# 0        6.402493         25
# 1        4.992523         50
# 2       13.020833        100
# 3       16.196824         25
# 4       12.234207         50
# 5       15.896885        100
# 6       -9.509411         25
# 7       -4.564972         50
# 8        3.539020        100
# 9       12.186429         25
# 10      11.929342         50
# 11      13.028909        100
# 12      -5.023526         25
# 13      11.087585         50
# 14       8.439201        100
# 15      10.676526         25
# 16       8.065882         50
# 17      10.748106        100

# %%
new_scores_path = os.path.join(scores_path,dataset_name, tipo, "inductive_%d.csv" % (dims))

print "Guardando en %s" % new_scores_path
df.to_csv(new_scores_path, columns=df.columns)
print "Resultados guardados."
# Out:
# Guardando en scores/twitter/pca/inductive_2000.csv
# Resultados guardados.
